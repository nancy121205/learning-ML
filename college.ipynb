# %%
2+3
# Out:
# 5

# %%
print('fwefn')
# Out:
# fwefn

# %%
import pandas

# %%
import pandas

# %%
import sklearn

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("Collage_Option_List.csv")

# %% [markdown]
# # This is college list

# %%
dataframe.head(58).tail(15)
# Out:
#     Sr No         UDISE                       Area District  \
# 43   44.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 44   45.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 45   46.0  2.721101e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 46   47.0  2.721101e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 47   48.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 48   49.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 49   50.0  2.721101e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 50   51.0  2.721101e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 51   52.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 52   53.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 53   54.0  2.721101e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 54   55.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 55   56.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 56   57.0  2.721101e+10  NAVI MUMBAI-URC1 (272110)    THANE
# 57   58.0  2.721100e+10  NAVI MUMBAI-URC1 (272110)    THANE
#
# ...

# %%
dataframe["Total Fee"].head(58).tail(14).plot(kind="pie")
# Out:
# <Axes: ylabel='Total Fee'>

# %%
import matplotlib.pyplot as plt

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 1AD6-6646
#
#  Directory of C:\Users\Nancy\anaconda\test_proj
#
# 07-06-2025  19:40    <DIR>          .
# 07-06-2025  12:15    <DIR>          ..
# 07-06-2025  19:40    <DIR>          .ipynb_checkpoints
# 07-06-2025  18:51            13,453 Collage_Option_List.csv
# 07-06-2025  19:09            34,761 college.ipynb
# 07-06-2025  12:22    <DIR>          env
# 07-06-2025  18:53               337 Untitled1.ipynb
#                3 File(s)         48,551 bytes
#                4 Dir(s)  147,763,875,840 bytes free
